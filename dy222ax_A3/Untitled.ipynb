# %%
import a3_4

# %%
X_train, y_train, X_test, y_test = a3_4.load_data()

# %%
X_train[0].reshape(-1,1).shape
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.imshow(X_train[0].reshape(28,28))
#plt.colorbar()
#plt.grid(False)
plt.show()

# %%
X_train.shape
# Out:
# (60000, 784)

# %%
X_train[0].reshape(28,28).shape
# Out:
# (28, 28)

# %%
import numpy as np

# %%
seed = 42
np.random.seed(seed)
r = np.random.permutation(len(X_train))
X_train, y_train = X_train[r, :], y_train[r]

# %%
for i in range(0,16):
    plt.figure()
    plt.imshow(X_train[i].reshape(28,28))
    #plt.colorbar()
    #plt.grid(False)
    plt.show()

# %%
from sklearn.neural_network import MLPClassifier

# %%
X_train_reduced = X_train[:20000,:]
y_train_reduced = y_train[:20000]
print(X_train_reduced.shape, y_train_reduced.shape)

# %%
# Out:
# (20000, 784) (20000,)

# %%
clf.fit(X_train_reduced,y_train_reduced)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)

# %%
clf.score(X_test,y_t                            est)
# Out:
# 0.8235

# %%
clf = MLPClassifier(early_stopping=False).fit(X_train_reduced,y_train_reduced)
clf.score(X_test,y_test)
# Out:
# 0.5738
