# %%
import a3_4
from sklearn.neural_network import MLPClassifier
import matplotlib.pyplot as plt
import numpy as np

# %%
X_train, y_train, X_test, y_test = a3_4.load_data()

# %%
X_train.shape
# Out:
# (60000, 784)

# %%
X_train[0].reshape(-1,1).shape
# Out:
# (784, 1)

# %%
X_train[0].shape
# Out:
# (784,)

# %%
X_train[0].reshape(28,28).shape
# Out:
# (28, 28)

# %%
X_train[0].shape
# Out:
# (784,)

# %%
plt.figure()
plt.imshow(X_train[0].reshape(28,28))
#plt.colorbar()
#plt.grid(False)
plt.show()

# %%
seed = 42
np.random.seed(seed)
r = np.random.permutation(len(X_train))
X_train, y_train = X_train[r, :], y_train[r]

# %%
for i in range(0,16):
    plt.figure()
    plt.imshow(X_train[i].reshape(28,28))
    #plt.colorbar()
    #plt.grid(False)
    plt.show()

# %%
a3_4.ex_4_1(X_train, y_train, X_test, y_test)
# Out:
# A3, Ex4.1
# randomize_data

# %%
num_reduced = 2000
X_train_reduced = X_train#[:num_reduced,:]
y_train_reduced = y_train#[:num_reduced]
print(X_train_reduced.shape, y_train_reduced.shape)
# Out:
# (60000, 784) (60000,)

# %%
clf = MLPClassifier(early_stopping=False)

# %%
clf.fit(X_train_reduced,y_train_reduced)
# Out:
# MLPClassifier()

# %%
# 2000, .7661
# 8000, .8143
# 12000, .8404
# 20000, .8428
# 40000, .848
# 60000, .848

clf.score(X_test,y_test)
# Out:
# 0.848

# %%
import assignment_3_funcs as as3f

# %%
svc_param = [{'hidden_layer_sizes':[(10,),(100,)], 'early_stopping':[False]}]
gscv = as3f.grid_search_SVC(X_train_reduced,y_train_reduced, MLPClassifier, 5, svc_param)
# Out:
# grid_search_SVC [{'hidden_layer_sizes': [(10,), (100,)], 'early_stopping': [False]}]
